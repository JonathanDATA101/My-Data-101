# %% [markdown]
# # Homework 1: Python Basics

# %% [markdown]
# - **Jonathan M21213275** <br> <br>

# %% [markdown]
# - *Data Science, Semester 1* <br> <br>

# %% [markdown]
# 1. **Three things I want to learn**
#     - *Python*
#     - *Fundamentals of handling Data*
#     - *Data Processing*

# %% [markdown]
# # Schedule
# | Class | Day/Time/Location | Credits
# |:---------:|:---------------------|:---------------------:|
# | Geology |      M/W 11 - 12:15 SCI Center  | 3
# | Geology (LAB) |   M/W  12:30 - 1:45 SCI Center | 3
# | Management | TU/THU 9:30 - 10:45 HU  | 3
# | Data |   TU/THU 12:30 - 1:45 SCI Center | 3

# %% [markdown]
# product_name = "Nintendo Switch 2"
#
# price = 499.99
#
# quantity = 100

# %% [markdown]
# price = int(price)
# print(type(price))

# %%
print(f"We have [100] units of [Nintendo Switch 2] available at $[499.99] each.")

# %% [markdown]
# # Multiply price by quantity to find total value
# total_value = price * quantity
# print(total_value)
#
# # Check if the total value is greater than 500
# is_greater = total_value > 500
# print(is_greater)

# %% [markdown]
# *I linked total_value to price x quantity to be able to measuere whether nor not my product exceeds 500, if it does the > will see and print is_greater*
